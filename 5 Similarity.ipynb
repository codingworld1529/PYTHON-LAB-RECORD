# %% [markdown]
# <a href="https://colab.research.google.com/github/codingworld1529/PYTHON-LAB-RECORD/blob/main/5%20Similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from difflib import SequenceMatcher
def string_similarity(str1, str2):
    # Create a SequenceMatcher object
    matcher = SequenceMatcher(None, str1, str2)
    # Return similarity ratio
    return matcher.ratio()
# Example usage:
s1 = "Python programs"
s2 = "Python Exercise"
print("Similarity:", string_similarity(s1, s2))
# Out:
# Similarity: 0.6
