# %% [markdown]
# <a href="https://colab.research.google.com/github/codingworld1529/PYTHON-LAB-RECORD/blob/main/1C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = input("Enter a number: ")
if number == number[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for i in range(10):
    count = number.count(str(i))
    if count > 0:
        print(f"{i} appears {count} times")
# Out:
# Enter a number: 4566
# Not Palindrome
# 4 appears 1 times
# 5 appears 1 times
# 6 appears 2 times
