# %% [markdown]
# <a href="https://colab.research.google.com/github/codingworld1529/PYTHON-LAB-RECORD/blob/main/2%20Fibonacci%20series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci_sequence(N):
  if N <= 0:
    print("Error: N must be greater than 0.")
    return
  fib_list = []
  a, b = 0, 1
  for _ in range(N):
    fib_list.append(a)
    a, b = b, a + b
  print("Fibonacci sequence up to", N, "terms:", fib_list)
try:
  N = int(input("Enter the number of terms (N > 0): "))
  fibonacci_sequence(N)
except ValueError:
  print("Error: Please enter a valid integer.")
# Out:
# Enter the number of terms (N > 0): 4
# Fibonacci sequence up to 4 terms: [0, 1, 1, 2]
